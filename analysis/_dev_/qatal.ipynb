# %% [markdown]
# # Analyzing the Translation Tendencies of the Qatal Verb

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tf.app import use
import stats.significance as sig

PROJ = Path.home().joinpath('github/CambridgeSemiticsLab/translation_traditions_HB/data/')
DATA_CSV = PROJ.joinpath('_private_/translation_dataset.csv')
verb_df = pd.read_csv(DATA_CSV)

# %%
verb_df.shape
# Out:
# (20332, 26)

# %%
verb_df.columns
# Out:
# Index(['bhsa_node', 'wlc_id', 'ref', 'book', 'text_full', 'text_plain', 'lex',
#        'lex_etcbc', 'gloss', 'tense', 'stem', 'person', 'gender', 'number',
#        'wlc_morph', 'sentence', 'genre', 'domain', 'txt_type', 'clause_type',
#        'clause_rela', 'preceding_waw', 'valence', 'niv_tags', 'niv_dep',
#        'niv_words'],
#       dtype='object')

# %%
verb_df.head()
# Out:
#    bhsa_node       wlc_id           ref     book text_full text_plain  lex  \
# 0          3  10010010021   Genesis 1:1  Genesis   בָּרָ֣א        ברא  ברא
# 1         15  10010020021   Genesis 1:2  Genesis  הָיְתָ֥ה       היתה  היה
# 2         69  10010050061   Genesis 1:5  Genesis    קָ֣רָא        קרא  קרא
# 3        172  10010100071  Genesis 1:10  Genesis    קָרָ֣א        קרא  קרא
# 4        267  10010150012  Genesis 1:15  Genesis    הָי֤וּ        היו  היה
#
#   lex_etcbc        gloss tense  ...  genre domain txt_type clause_type  \
# 0      BR>[   he created  perf  ...  prose      ?        ?        xQtX
# 1      HJH[      she was  perf  ...  prose      ?        ?        WXQt
# 2      QR>[    he called  perf  ...  prose      N       ?N        WxQ0
# 3      QR>[    he called  perf  ...  prose      N       ?N        WxQ0
# 4      HJH[  let them be  perf  ...  prose      Q      ?NQ        WQt0
#
#   clause_rela preceding_waw valence niv_tags     niv_dep niv_words
# 0        Main         False      d-      VBD        ROOT   created
# 1        Main         False      --      VBD        ROOT       was
# 2        Main         False      l.      VBD       relcl    called
# 3        Main         False      l.      VBD       relcl    called
# 4        Main          True      -p    VB|VB  ROOT|ccomp    let be
#
# [5 rows x 26 columns]

# %%
verb_df.niv_tags.value_counts().head(25)
# Out:
# VBD          3835
# MD|VB        2161
# VBP|VBN      1557
# VB           1421
# VBZ          1183
# VBD|VBN      1113
# VBZ|VBN      1005
# VBP           968
# VBD|RP        354
# VBD|VB        353
# NN            250
# MD|VB|VBN     243
# VBD|JJ        233
# VBN           230
# MD|VB|RP      207
# VBG           181
# VBZ|TO|VB     138
# VBP|JJ        137
# MD|VB|JJ      131
# VBP|VB        131
# JJ            127
# VBD|RB        113
# VB|RP         110
# VBD|IN        110
# VBZ|JJ        106
# Name: niv_tags, dtype: int64

# %% [markdown]
# ### Gesenius Groups
#
# * Events in past §106.1
#     * a "english perfect definite", e.g. "did VB"
#     * tempus historicum (VBD)
#     * pluperfect "have + past participle"
#
# * Events in past with remaining effects §106.2
#     * have + present tense verb
#
# * Events in future

# %%
verb_df.clause_rela.value_counts()
# Out:
# Main      14646
# SubAdv     2891
# SubMod     2342
# SubArg      453
# Name: clause_rela, dtype: int64

# %% [markdown]
# # Looking at the modal uses of qatal

# %%
# add some new boolean columns to check for various 
# predictors of modality
verb_df['has_modal'] = verb_df.niv_tags.str.match('MD') 
verb_df['is_prose'] = verb_df.genre == 'prose'
verb_df['is_speech'] = verb_df.domain == 'Q'
verb_df['is_main'] = verb_df.clause_rela == 'Main'

# %%
# run some correlation statistics with various relevant factors

modal_corr = pd.pivot_table(
    verb_df,
    index=['has_modal'],
    columns=['preceding_waw', 'is_prose', 'is_speech', 'is_main'],
    aggfunc='size',
    fill_value=0,
)

# %%
modal_corr
# Out:
# preceding_waw False                                           True         \
# is_prose      False                   True                    False
# is_speech     False       True        False       True        False
# is_main       False True  False True  False True  False True  False True
# has_modal
# False           518  1194  1848  3562  1436  1986  1513  1573     9   318
# True             10    35    80   289     8    67    31    42     4   187
#
# preceding_waw
# is_prose                  True
# is_speech     True        False       True
# is_main       False True  False True  False True
# has_modal
# False           114  1760     9   216    75   945
# True             20  1775     0    35    11   662

# %%
modal_prop = modal_corr.div(modal_corr.sum(1), 0)

modal_prop
# Out:
# preceding_waw     False                                                    \
# is_prose          False                                   True
# is_speech         False               True                False
# is_main           False     True      False     True      False     True
# has_modal
# False          0.030335  0.069923  0.108222  0.208597  0.084095  0.116304
# True           0.003071  0.010749  0.024570  0.088759  0.002457  0.020577
#
# preceding_waw                         True                                 \
# is_prose                              False
# is_speech         True                False               True
# is_main           False     True      False     True      False     True
# has_modal
# False          0.088604  0.092118  0.000527  0.018623  0.006676  0.103069
# True           0.009521  0.012899  0.001229  0.057432  0.006143  0.545147
#
# preceding_waw
# is_prose          True
# is_speech         False               True
# is_main           False     True      False     True
# has_modal
# False          0.000527  0.012649  0.004392  0.055341
# True           0.000000  0.010749  0.003378  0.203317

# %%
# run some correlation tests

modal_fish, odds = sig.apply_fishers(modal_corr, 0, 1)

modal_fish
# Out:
#            False                                                        \
#            False                                      True
#            False                 True                 False
#            False      True       False     True       False      True
# False  26.781137  52.351673  64.584147  65.47773  98.527008  82.402339
# True  -26.781137 -52.351673 -64.584147 -65.47773 -98.527008 -82.402339
#
#                                 True                                        \
#                                 False                                True
#            True                 False                True            False
#            False      True      False      True      False True      False
# False  78.230193  73.017645 -0.848723 -30.345932  0.089587  -inf  0.430628
# True  -78.230193 -73.017645  0.848723  30.345932 -0.089587   inf -0.430628
#
#
#
#                     True
#           True      False      True
# False  0.361182  0.256057 -141.57634
# True  -0.361182 -0.256057  141.57634

# %%
# see which features cue the modal response

corr_modal = modal_corr.T

corr_modal
# Out:
# has_modal                                 False  True
# preceding_waw is_prose is_speech is_main
# False         False    False     False      518     10
#                                  True      1194     35
#                        True      False     1848     80
#                                  True      3562    289
#               True     False     False     1436      8
#                                  True      1986     67
#                        True      False     1513     31
#                                  True      1573     42
# True          False    False     False        9      4
#                                  True       318    187
#                        True      False      114     20
#                                  True      1760   1775
#               True     False     False        9      0
#                                  True       216     35
#                        True      False       75     11
#                                  True       945    662

# %%
def color_dp(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'blue' if val < 0 else 'red'
    return f'color: {color}'

# %%
corr_delt = sig.apply_deltaP(corr_modal, 0, 1)

corr_delt.style.applymap(color_dp)
# Out:
# <style  type="text/css" >
#     #T_6db37b8c_e618_11ea_bb53_8c859073a1earow0_col0 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow0_col1 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow1_col0 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow1_col1 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow2_col0 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow2_col1 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow3_col0 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow3_col1 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow4_col0 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow4_col1 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow5_col0 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow5_col1 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow6_col0 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow6_col1 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow7_col0 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow7_col1 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow8_col0 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow8_col1 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow9_col0 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow9_col1 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow10_col0 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow10_col1 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow11_col0 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow11_col1 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow12_col0 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow12_col1 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow13_col0 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow13_col1 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow14_col0 {
#             color:  red;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow14_col1 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow15_col0 {
#             color:  blue;
#         }    #T_6db37b8c_e618_11ea_bb53_8c859073a1earow15_col1 {
#             color:  red;
#         }</style><table id="T_6db37b8c_e618_11ea_bb53_8c859073a1ea" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="index_name level0" >has_modal</th>        <th class="col_heading level0 col0" >False</th>        <th class="col_heading level0 col1" >True</th>    </tr>    <tr>        <th class="index_name level0" >preceding_waw</th>        <th class="index_name level1" >is_prose</th>        <th class="index_name level2" >is_speech</th>        <th class="index_name level3" >is_main</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel0_row0" class="row_heading level0 row0" rowspan=8>False</th>
#                         <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel1_row0" class="row_heading level1 row0" rowspan=4>False</th>
#                         <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel2_row0" class="row_heading level2 row0" rowspan=2>False</th>
#                         <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel3_row0" class="row_heading level3 row0" >False</th>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow0_col0" class="data row0 col0" >0.144967</td>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow0_col1" class="data row0 col1" >-0.144967</td>
#             </tr>
#             <tr>
#                                                 <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel3_row1" class="row_heading level3 row1" >True</th>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow1_col0" class="data row1 col0" >0.140134</td>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow1_col1" class="data row1 col1" >-0.140134</td>
#             </tr>
#             <tr>
#                                         <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel2_row2" class="row_heading level2 row2" rowspan=2>True</th>
#                         <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel3_row2" class="row_heading level3 row2" >False</th>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow2_col0" class="data row2 col0" >0.131077</td>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow2_col1" class="data row2 col1" >-0.131077</td>
#             </tr>
#             <tr>
#                                                 <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel3_row3" class="row_heading level3 row3" >True</th>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow3_col0" class="data row3 col0" >0.10498</td>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow3_col1" class="data row3 col1" >-0.10498</td>
#             </tr>
#             <tr>
#                                 <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel1_row4" class="row_heading level1 row4" rowspan=4>True</th>
#                         <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel2_row4" class="row_heading level2 row4" rowspan=2>False</th>
#                         <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel3_row4" class="row_heading level3 row4" >False</th>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow4_col0" class="data row4 col0" >0.166421</td>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow4_col1" class="data row4 col1" >-0.166421</td>
#             </tr>
#             <tr>
#                                                 <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel3_row5" class="row_heading level3 row5" >True</th>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow5_col0" class="data row5 col0" >0.141827</td>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow5_col1" class="data row5 col1" >-0.141827</td>
#             </tr>
#             <tr>
#                                         <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel2_row6" class="row_heading level2 row6" rowspan=2>True</th>
#                         <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel3_row6" class="row_heading level3 row6" >False</th>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow6_col0" class="data row6 col0" >0.151574</td>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow6_col1" class="data row6 col1" >-0.151574</td>
#             </tr>
#             <tr>
#                                                 <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel3_row7" class="row_heading level3 row7" >True</th>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow7_col0" class="data row7 col0" >0.145709</td>
#                         <td id="T_6db37b8c_e618_11ea_bb53_8c859073a1earow7_col1" class="data row7 col1" >-0.145709</td>
#             </tr>
#             <tr>
#                         <th id="T_6db37b8c_e618_11ea_bb53_8c859073a1ealevel0_row8" class="row_heading level0 row8" rowspan=8>True</th>

# %%
verb_df

# %% [markdown]
# ### Key Observations
#
# ```
# --------
#
# * There are no cases where the absence of a preceding waw
# strongly predicts a modal context.
#
# -------
#
# * 40% more likely to see modal translation
#     preceding_waw    True
#     is_prose         False
#     is_speech        True
#     is_main          True
#
# -------
#
# However, the waw is clearly not the only factor:
#
# * 16% more likely to see a NON-modal translation
#     preceding_waw    True
#     is_prose         True
#     is_speech        False
#     is_main          False
#
# ```
